# %% [markdown]
# # 0. Install and Import Dependencies

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\anaconda3\lib\site-packages (0.8.4)
# Requirement already satisfied: opencv-python in c:\anaconda3\lib\site-packages (4.5.1.48)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: scikit-learn in c:\anaconda3\lib\site-packages (0.20.3)
# Requirement already satisfied: numpy in c:\anaconda3\lib\site-packages (from mediapipe) (1.16.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\anaconda3\lib\site-packages (from mediapipe) (19.1.0)
# Requirement already satisfied: wheel in c:\anaconda3\lib\site-packages (from mediapipe) (0.33.1)
# Requirement already satisfied: absl-py in c:\anaconda3\lib\site-packages (from mediapipe) (0.12.0)
# Requirement already satisfied: opencv-contrib-python in c:\anaconda3\lib\site-packages (from mediapipe) (4.5.1.48)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from mediapipe) (1.12.0)
# Requirement already satisfied: protobuf>=3.11.4 in c:\anaconda3\lib\site-packages (from mediapipe) (3.15.8)
# Requirement already satisfied: pytz>=2011k in c:\anaconda3\lib\site-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\anaconda3\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: scipy>=0.13.3 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.2.1)

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Make Some Detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
    
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('s'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV
# <!--<img src="https://i.imgur.com/8bForKY.png">-->
# <!--<img src="https://i.imgur.com/AzKNp7A.png">-->

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.face_landmarks.landmark)
num_coords
# Out:
# 468

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting = csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "other person"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )

        try:
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x,landmark.y,landmark.z,landmark.visibility] for landmark in face]).flatten())
            
            row = face_row
            row.insert(0, class_name)
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)
        except:
            pass
        
        
      
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('s'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#     class        x1        y1        z1   v1        x2        y2        z2  \
# 0  master  0.503850  0.659959 -0.038595  0.0  0.505261  0.580895 -0.082376
# 1  master  0.502653  0.659736 -0.039650  0.0  0.504432  0.578431 -0.082736
# 2  master  0.499070  0.662619 -0.040522  0.0  0.500532  0.579246 -0.082580
# 3  master  0.492840  0.661821 -0.040480  0.0  0.494047  0.582263 -0.080868
# 4  master  0.489348  0.664610 -0.040437  0.0  0.490068  0.583703 -0.081792
#
#     v2        x3  ...      z466  v466      x467      y467      z467  v467  \
# 0  0.0  0.504908  ... -0.018127   0.0  0.624136  0.433368  0.010500   0.0
# 1  0.0  0.503462  ... -0.016378   0.0  0.619820  0.430510  0.013516   0.0
# 2  0.0  0.499755  ... -0.015712   0.0  0.614923  0.434018  0.013187   0.0
# 3  0.0  0.493222  ... -0.014300   0.0  0.605174  0.437765  0.014252   0.0
# 4  0.0  0.489895  ... -0.015674   0.0  0.604342  0.440476  0.012053   0.0
#
#        x468      y468      z468  v468
# 0  0.632601  0.421482  0.011214   0.0
# 1  0.628167  0.418570  0.014409   0.0
# 2  0.623388  0.422059  0.013965   0.0
# 3  0.613560  0.425686  0.015068   0.0
# 4  0.612724  0.428649  0.012768   0.0
#
# [5 rows x 1873 columns]

# %%
df.tail()
# Out:
#             class        x1        y1        z1   v1        x2        y2  \
# 934  other person  0.499101  0.735493 -0.033538  0.0  0.496090  0.665433
# 935  other person  0.562803  0.711962 -0.033656  0.0  0.564968  0.642147
# 936  other person  0.629537  0.694692 -0.036958  0.0  0.636340  0.624047
# 937  other person  0.673625  0.709030 -0.037514  0.0  0.677000  0.629919
# 317  0.058859   0.0  0.696822  0.331650  0.062097   0.0
# 318  0.058008   0.0  0.699081  0.336714  0.061212   0.0
# 319  0.058092   0.0  0.695971  0.334218  0.061349   0.0
# 320  0.055523   0.0  0.695864  0.331783  0.058692   0.0
# ..        ...   ...       ...       ...       ...   ...
# 909  0.003819   0.0  0.609175  0.464504  0.003725   0.0
# 910  0.005350   0.0  0.616830  0.463831  0.005381   0.0
# 911  0.008189   0.0  0.624336  0.462741  0.008448   0.0
# 912  0.012703   0.0  0.634854  0.461523  0.013313   0.0
# 913  0.024387   0.0  0.652667  0.455555  0.025700   0.0
# 914  0.029097   0.0  0.656773  0.453123  0.030678   0.0
# 915  0.031735   0.0  0.660566  0.450161  0.033475   0.0
# 916  0.034525   0.0  0.665303  0.450310  0.036445   0.0
# 917  0.037507   0.0  0.665400  0.446832  0.039555   0.0
# 918  0.038192   0.0  0.666766  0.447392  0.040318   0.0
# 919  0.037925   0.0  0.666429  0.445937  0.040112   0.0
# 920  0.039641   0.0  0.666110  0.446928  0.041879   0.0
# 921  0.038369   0.0  0.665548  0.446409  0.040517   0.0
# 922  0.037263   0.0  0.664287  0.446416  0.039409   0.0
# 923  0.036815   0.0  0.662062  0.446730  0.038869   0.0
# 924  0.033140   0.0  0.659400  0.447163  0.034971   0.0
# 925  0.029955   0.0  0.651401  0.452898  0.031579   0.0
# 926  0.023995   0.0  0.645128  0.454969  0.025278   0.0
# 927  0.017348   0.0  0.638113  0.457708  0.018138   0.0
# 928  0.015611   0.0  0.636785  0.460361  0.016298   0.0
# 929  0.013820   0.0  0.633574  0.463775  0.014318   0.0
# 930  0.009638   0.0  0.626951  0.464316  0.009889   0.0
# 931  0.007636   0.0  0.622079  0.466703  0.007641   0.0
# 932  0.001783   0.0  0.612831  0.467103  0.001307   0.0
# 933 -0.008115   0.0  0.604407  0.468590 -0.009029   0.0
# 934 -0.004560   0.0  0.628579  0.474211 -0.004872   0.0
# 935  0.010928   0.0  0.680053  0.459735  0.011573   0.0
# 936  0.020571   0.0  0.748014  0.440958  0.021690   0.0
# 937  0.014472   0.0  0.806880  0.441071  0.015141   0.0
# 938  0.006870   0.0  1.039400  0.475633  0.006681   0.0
#
# [347 rows x 1873 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 29           master
# 862    other person
# 166          master
# 637          master
# 931    other person
# 721          master
# 413    other person
# 271          master
# 583          master
# 567          master
# 646          master
# 143          master
# 281          master
# 128          master
# 118          master
# 348    other person
# 89           master
# 276          master
# 141          master
# 40           master
# 807    other person
# 832    other person
# 699          master
# 604          master
# 146          master
# 876    other person
# 518          master
# 844    other person
# 588          master
# 277          master
#            ...
# 331    other person
# 532          master
# 496          master
# 297    other person
# 194          master
# 543          master
# 171          master
# 438          master
# 44           master
# 641          master
# 389    other person
# 187          master
# 801    other person
# 216          master
# 310    other person
# 96           master
# 744    other person
# 218          master
# 544          master
# 170          master
# 932    other person
# 599          master
# 924    other person
# 919    other person
# 145          master
# 70           master
# 157          master
# 347    other person
# 121          master
# 342    other person
# Name: class, Length: 282, dtype: object

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
classifier = LogisticRegression(random_state = 0, solver='lbfgs')

# %%
fit_models
# Out:
# {'lr': Pipeline(memory=None,
#       steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('logisticregression', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='warn',
#            n_jobs=None, penalty='l2', random_state=None, solver='warn',
#            tol=0.0001, verbose=0, warm_start=False))]),
#  'rc': Pipeline(memory=None,
#       steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('ridgeclassifier', RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#          max_iter=None, normalize=False, random_state=None, solver='auto',
#          tol=0.001))]),
#  'rf': Pipeline(memory=None,
#       steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('randomforestclassifier', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min...obs=None,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False))]),
#  'gb': Pipeline(memory=None,
#       steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('gradientboostingclassifier', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                learning_rate=0.1, loss='deviance', max_depth=3,
#                max_features=None, max_leaf_nodes=None,
#     ...    subsample=1.0, tol=0.0001, validation_fraction=0.1,
#                verbose=0, warm_start=False))])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['master', 'other person', 'master', 'master', 'other person',
#        'master', 'other person', 'master', 'master', 'master', 'master',
#        'master', 'master', 'master', 'master', 'other person', 'master',
#        'master', 'master', 'master', 'other person', 'other person',
#        'master', 'master', 'master', 'other person', 'master',
#        'other person', 'master', 'master', 'master', 'other person',
#        'master', 'master', 'master', 'master', 'master', 'master',
#        'master', 'master', 'master', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master',
#        'other person', 'other person', 'master', 'master', 'master',
#        'other person', 'master', 'master', 'other person', 'master',
#        'master', 'master', 'other person', 'other person', 'master',
#        'other person', 'other person', 'master', 'other person',
#        'other person', 'master', 'master', 'master', 'other person',
#        'other person', 'other person', 'master', 'master', 'other person',
#        'master', 'master', 'other person', 'master', 'other person',
#        'other person', 'other person', 'other person', 'master', 'master',
#        'other person', 'master', 'other person', 'other person',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'other person', 'master', 'other person', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master',
#        'other person', 'master', 'master', 'master', 'other person',
#        'other person', 'master', 'master', 'other person', 'master',
#        'master', 'other person', 'other person', 'master', 'master',
#        'master', 'master', 'master', 'master', 'master', 'other person',
#        'other person', 'master', 'other person', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master', 'master',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'master', 'other person', 'master', 'other person', 'other person',
#        'master', 'master', 'other person', 'master', 'other person',
#        'master', 'master', 'master', 'other person', 'other person',
#        'other person', 'other person', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'other person', 'master',
#        'master', 'master', 'other person', 'master', 'other person',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master',
#        'other person', 'master', 'master', 'other person', 'other person',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'master', 'master', 'master', 'master', 'other person', 'master',
#        'master', 'other person', 'master', 'other person', 'other person',
#        'other person', 'other person', 'master', 'master', 'other person',
#        'master', 'other person', 'master', 'other person', 'other person',
#        'master', 'master', 'other person', 'master', 'master',
#        'other person', 'master', 'other person', 'other person', 'master',
#        'other person', 'master', 'master', 'master', 'other person',
#        'other person', 'master', 'master', 'other person', 'master',
#        'master', 'master', 'master', 'master', 'master', 'other person',
#        'master', 'other person', 'master', 'other person', 'master',
#        'other person', 'master', 'master', 'master', 'other person',
#        'master', 'other person', 'other person', 'master', 'master',
#        'master', 'other person', 'master', 'other person'], dtype='<U12')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 0.9964539007092199
# rf 0.9893617021276596
# gb 0.9929078014184397

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['master', 'other person', 'master', 'master', 'other person',
#        'master', 'other person', 'master', 'master', 'master', 'master',
#        'master', 'master', 'master', 'master', 'other person', 'master',
#        'master', 'master', 'master', 'other person', 'other person',
#        'master', 'master', 'master', 'other person', 'master',
#        'other person', 'master', 'master', 'master', 'other person',
#        'master', 'master', 'master', 'master', 'master', 'master',
#        'master', 'master', 'master', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master',
#        'other person', 'other person', 'master', 'master', 'master',
#        'other person', 'master', 'master', 'other person', 'master',
#        'master', 'master', 'other person', 'other person', 'master',
#        'other person', 'other person', 'master', 'other person',
#        'other person', 'master', 'master', 'master', 'other person',
#        'other person', 'other person', 'master', 'master', 'other person',
#        'master', 'master', 'other person', 'master', 'other person',
#        'other person', 'other person', 'other person', 'master', 'master',
#        'other person', 'master', 'other person', 'other person',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'other person', 'master', 'other person', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master',
#        'other person', 'master', 'master', 'master', 'other person',
#        'other person', 'master', 'master', 'other person', 'master',
#        'master', 'other person', 'other person', 'master', 'master',
#        'master', 'master', 'master', 'master', 'master', 'other person',
#        'other person', 'master', 'other person', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master', 'master',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'master', 'other person', 'master', 'other person', 'other person',
#        'master', 'master', 'other person', 'master', 'other person',
#        'master', 'master', 'master', 'other person', 'other person',
#        'other person', 'other person', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'other person', 'master',
#        'master', 'master', 'other person', 'master', 'other person',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master', 'master',
#        'master', 'master', 'other person', 'master', 'master',
#        'other person', 'master', 'master', 'other person', 'other person',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'master', 'master', 'master', 'master', 'other person', 'master',
#        'master', 'other person', 'master', 'other person', 'other person',
#        'other person', 'other person', 'master', 'master', 'other person',
#        'master', 'master', 'master', 'other person', 'other person',
#        'master', 'master', 'other person', 'master', 'master',
#        'other person', 'master', 'other person', 'other person', 'master',
#        'other person', 'master', 'master', 'master', 'other person',
#        'other person', 'master', 'master', 'other person', 'master',
#        'master', 'master', 'master', 'master', 'master', 'other person',
#        'master', 'other person', 'master', 'other person', 'master',
#        'other person', 'master', 'master', 'master', 'master', 'master',
#        'other person', 'other person', 'master', 'master', 'master',
#        'other person', 'master', 'other person'], dtype=object)

# %%
y_test
# Out:
# 29           master
# 862    other person
# 166          master
# 637          master
# 931    other person
# 721          master
# 413    other person
# 271          master
# 583          master
# 567          master
# 646          master
# 143          master
# 281          master
# 128          master
# 118          master
# 348    other person
# 89           master
# 276          master
# 141          master
# 40           master
# 807    other person
# 832    other person
# 699          master
# 604          master
# 146          master
# 876    other person
# 518          master
# 844    other person
# 588          master
# 277          master
#            ...
# 331    other person
# 532          master
# 496          master
# 297    other person
# 194          master
# 543          master
# 171          master
# 438          master
# 44           master
# 641          master
# 389    other person
# 187          master
# 801    other person
# 216          master
# 310    other person
# 96           master
# 744    other person
# 218          master
# 544          master
# 170          master
# 932    other person
# 599          master
# 924    other person
# 919    other person
# 145          master
# 70           master
# 157          master
# 347    other person
# 121          master
# 342    other person
# Name: class, Length: 282, dtype: object

# %%
with open('face.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
with open('face.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('randomforestclassifier', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min...obs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        
        
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )

        # Export coordinates
        try:

            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = face_row
            

            X = pd.DataFrame([row])
            face_class = model.predict(X)[0]
            face_prob = model.predict_proba(X)[0]
            print(face_class, face_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.face_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.face_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [320,240]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(face_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, face_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, face_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(face_prob[np.argmax(face_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# other person [0.3 0.7]
# master [0.8 0.2]
# master [0.8 0.2]
# master [0.8 0.2]
# master [0.8 0.2]
# master [0.6 0.4]
# master [0.8 0.2]
# master [0.8 0.2]
# master [0.9 0.1]
# master [0.9 0.1]
# master [0.9 0.1]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# master [1. 0.]
# other person [0. 1.]
# other person [0.2 0.8]
# other person [0.1 0.9]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0.1 0.9]
# other person [0. 1.]
# other person [0.1 0.9]
# other person [0. 1.]
# other person [0.1 0.9]
# other person [0.1 0.9]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0.1 0.9]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# other person [0. 1.]
# master [0.7 0.3]
# other person [0. 1.]
# master [0.6 0.4]
# master [0.7 0.3]
# other person [0.4 0.6]
# master [0.7 0.3]
# master [0.6 0.4]
# master [0.7 0.3]
# master [0.7 0.3]
# master [0.5 0.5]
# master [0.5 0.5]
# other person [0.3 0.7]
# other person [0.2 0.8]
# other person [0.2 0.8]
# master [0.5 0.5]
# master [0.7 0.3]
# master [0.7 0.3]
# other person [0.2 0.8]
# other person [0.1 0.9]
# other person [0.2 0.8]
# other person [0.1 0.9]
# other person [0.2 0.8]
# other person [0. 1.]
# other person [0.2 0.8]
# other person [0. 1.]
# other person [0. 1.]
# other person [0.2 0.8]
# other person [0.1 0.9]
# other person [0. 1.]
# other person [0. 1.]
# other person [0.1 0.9]
# master [1. 0.]
# master [1. 0.]
# master [0.8 0.2]
# master [1. 0.]
# master [0.6 0.4]

# %%
tuple(np.multiply(np.array((results.face_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.face_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [320,240]).astype(int))
# Out:
# (135, 99)
